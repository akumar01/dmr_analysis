# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from helpers import *
from pynwb import NWBHDF5IO
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import correlate
from math import floor, ceil

# %%
# Load in nwb file
io = NWBHDF5IO('R32_B8.nwb')
nwbfile = io.read()

# %% [markdown]
# # Provide a few representative autocorrelation plots #

# %%
# Single high gamma channel, arbitrary time:
g = np.array(nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].data[:, 104, 29])
g = downsample(g)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]

# %%
g_a = np.correlate(g[8000:8200] - np.mean(g[8000:8200]), g[8000:8200] - np.mean(g[8000:8200]), mode = 'same')
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(g_a/np.max(g_a))
plt.title('Autocorrelation, Freq. Channel 29, Electrode 105, 81 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorr_singlechannel_1.png')

# %%
g_a = np.correlate(g[16000:16200] - np.mean(g[16000:16200]), g[16000:16200] - np.mean(g[16000:16200]), mode = 'same')
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(g_a/np.max(g_a))
plt.title('Autocorrelation, Freq. Channel 29, Electrode 105, 161 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorr_singlechannel_2.png')

# %%
g_a = np.correlate(g[64000:64200] - np.mean(g[64000:64200]), g[64000:64200] - np.mean(g[64000:64200]), mode = 'same')
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(g_a/np.max(g_a))
plt.title('Autocorrelation, Freq. Channel 29, Electrode 105, 641 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorr_singlechannel_3.png')

# %%
# Different high gamme channel:
g = np.array(nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].data[:, 104, 36])
g = downsample(g)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]

# %%
g_a = np.correlate(g[8000:8200] - np.mean(g[8000:8200]), g[8000:8200] - np.mean(g[8000:8200]), mode = 'same')
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(g_a/np.max(g_a))
plt.title('Autocorrelation, Freq. Channel 36, Electrode 105, 81 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorr_singlechannel_4.png')

# %%
g_a = np.correlate(g[16000:16200] - np.mean(g[16000:16200]), g[16000:16200] - np.mean(g[16000:16200]), mode = 'same')
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(g_a/np.max(g_a))
plt.title('Autocorrelation, Freq. Channel 36, Electrode 105, 161 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorr_singlechannel_5.png')

# %%
g_a = np.correlate(g[64000:64200] - np.mean(g[64000:64200]), g[64000:64200] - np.mean(g[64000:64200]), mode = 'same')
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(g_a/np.max(g_a))
plt.title('Autocorrelation, Freq. Channel 36, Electrode 105, 641 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorr_singlechannel_6.png')

# %% [markdown]
# # Width of the autocorrelation peak over the entire data-set

# %%
g1 = np.array(nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].data[:, 104, 29])
g1 = downsample(g1)
g2 = np.array(nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].data[:, 104, 36])
g2 = downsample(g2)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]

# %% [markdown]
# ## First using a fixed window

# %%
a1 = autocorr_width(g1)
a2 = autocorr_width(g2)

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(a1)
plt.title('Autocorrelation Zero Time, Freq. Channel 29, Electrode 105, 2 second windows')
plt.ylabel('Autocorrelation zero Time')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t * 2 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorrwidth_singlechannel_1.png')

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(a2)
plt.title('Autocorrelation Zero Time, Freq. Channel 36, Electrode 105, 2 second windows')
plt.ylabel('Autocorrelation zero Time')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t * 2 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorrwidth_singlechannel_2.png')

# %% [markdown]
# ## Using a sliding window

# %%
a1 = autocorr_width(g1, 'sliding')
a2 = autocorr_width(g2, 'sliding')

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(a1)
plt.title('Autocorrelation Zero Time, Freq. Channel 29, Electrode 105, 2 second sliding windows')
plt.ylabel('Autocorrelation zero Time')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorrwidth_singlechannel_3.png')

# %% [markdown]
# fig = plt.figure(figsize = (15, 10))
# a = fig.add_subplot(111)
# plt.plot(a2)
# plt.title('Autocorrelation Zero Time, Freq. Channel 36, Electrode 105, 2 second sliding windows')
# plt.ylabel('Autocorrelation zero Time')
# plt.xlabel('Time (s)')
# ticks = a.get_xticks().tolist()
# ticks[:] = [t/100 for t in ticks]
# a.set_xticklabels(ticks)
# plt.savefig('Figures/091918/autocorrwidth_singlechannel_4.png')

# %% [markdown]
# ## Average together all gamma-channels using baseline z-scoring

# %%
gavg = get_gamma_from_grid([104], 'baseline', False)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]

# %%
gavg.shape
# Out:
# (94735, 1)

# %%
# Typical autocorrelations for averaged high gamma signals at various times
gavg_a = np.correlate((gavg[8000:8200] - np.mean(gavg[8000:8200])).flatten(), (gavg[8000:8200] - np.mean(gavg[8000:8200])).flatten(), mode = 'same')
second_derivative = np.diff(gavg_a, 2)
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(gavg_a/np.max(gavg_a))
plt.plot(second_derivative/np.max(second_derivative))
plt.title('Autocorrelation, Electrode 105, Averaged High Gamma Channels, 81 seconds into response')
plt.ylabel('Normalized amplitude')
plt.xlabel('Delay (s)')
plt.grid()
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
a.legend(['Normalized Autocorrelation', 'Normalized Second Derivative'])
plt.savefig('Figures/091918/averaged_autocorr_1a.png')

# %%
gavg_a = np.correlate((gavg[16000:16200] - np.mean(gavg[16000:16200])).flatten(), (gavg[16000:16200] - np.mean(gavg[16000:16200])).flatten(), mode = 'same')
second_derivative = np.diff(gavg_a, 2)
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(gavg_a/np.max(gavg_a))
plt.plot(second_derivative/np.max(second_derivative))
plt.grid()
plt.title('Autocorrelation, Electrode 105, Averaged High Gamma Channels, 161 seconds into response')
plt.ylabel('Normalized amplitude')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
a.legend(['Normalized Autocorrelation', 'Normalized Second Derivative'])
plt.savefig('Figures/091918/averaged_autocorr_2a.png')

# %%
gavg_a = np.correlate((gavg[64000:64200] - np.mean(gavg[64000:64200])).flatten(), (gavg[64000:64200] - np.mean(gavg[64000:64200])).flatten(), mode = 'same')
second_derivative = np.diff(gavg_a, 2)
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(gavg_a/np.max(gavg_a))
plt.plot(second_derivative/np.max(second_derivative))
plt.grid()
plt.title('Autocorrelation, Electrode 105, Averaged High Gamma Channels, 641 seconds into response')
plt.ylabel('Normalized autocorrelation')
plt.xlabel('Delay (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [(t - 100)/100 for t in ticks]
a.set_xticklabels(ticks)
a.legend(['Normalized Autocorrelation', 'Normalized Second Derivative'])
plt.savefig('Figures/091918/averaged_autocorr_3a.png')

# %% [markdown]
# ## Autocorrelation width for averaged high gamma signal

# %%
#gavg_width1 = autocorr_width(gavg.flatten(), 'fixed')
gavg_width2 = autocorr_width(gavg.flatten(), 'sliding')
# Out:
# > c:\users\ankit\odrive\berkeley google drive\bouchard\helpers.py(91)autocorr_width()
# -> for i in range(window_length, len(data)):
# (Pdb) import matplotlib.pyplot as plt
# (Pdb) plt.plot(autocorr)
# ...
# (Pdb) plt.show()
# (Pdb) quit()
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-135-e7551a11af2b> in <module>()
#       1 #gavg_width1 = autocorr_width(gavg.flatten(), 'fixed')
# ----> 2 gavg_width2 = autocorr_width(gavg.flatten(), 'sliding')
#
# ~\odrive\Berkeley Google Drive\bouchard\helpers.py in autocorr_width(data, mode)
#      89                 np.seterr(all='raise')
#      90
# ---> 91                 for i in range(window_length, len(data)):
#      92                         dat = data[i:min(i+window_length, len(data))] - np.mean(data[i:min(i+window_length, len(data))])
#      93                         try:
#
# ...

# %%
np.argmax(gavg_width2)
# Out:
# 29841

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(gavg_width1)
plt.title('Autocorrelation Zero Time, Averaged High Gamma, Electrode 105, 2 second windows')
plt.ylabel('Autocorrelation Zero Time (ms)')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t * 2 for t in ticks]
yticks = a.get_yticks().tolist()
yticks[:] = [t * 10 for t in yticks]
a.set_yticklabels(yticks)
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorrwidth_averaged_1.png')

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(gavg_width2)
plt.title('Autocorrelation Zero Time, Averaged High Gamma, Electrode 105, 2 second sliding windows')
plt.ylabel('Autocorrelation Zero Time (ms)')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
a.set_xticklabels(ticks)
yticks = a.get_yticks().tolist()
yticks[:] = [t * 10 for t in yticks]
a.set_yticklabels(yticks)
plt.savefig('Figures/091918/autocorrwidth_averaged_2.png')

# %%
sdw = second_derivative_width(gavg, mode='sliding')

# %%
# Out:
# 34503

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(sdw)
plt.title('Autocorrelation Inflection Point, Averaged High Gamma, Electrode 105, 2 second sliding windows')
plt.ylabel('Inflection point delay time (ms)')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
a.set_xticklabels(ticks)
yticks = a.get_yticks().tolist()
yticks[:] = [t * 10 for t in yticks]
a.set_yticklabels(yticks)
plt.savefig('Figures/091918/sd_width.png')

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(sdw[2])
plt.title('Autocorrelation Inflection Point, Averaged High Gamma, Electrode 105, 2 second sliding windows')
plt.ylabel('Inflection point (ms)')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
a.set_xticklabels(ticks)
yticks = a.get_yticks().tolist()
yticks[:] = [t * 10 for t in yticks]
a.set_yticklabels(yticks)
plt.savefig('Figures/091918/sd_width_zoom1.png')

# %% [markdown]
# # Sliding Z-score

# %%
gavg_moving = get_gamma_from_grid([104], 'moving', False)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]

# %%
fig = plt.figure(figsize = (15, 20))
a1 = fig.add_subplot(211)
plt.plot(gavg_moving)
plt.title('Electrode 105, Averaged High Gamma using moving Z-scoring')
plt.xlabel('Time (s)')
plt.ylabel('Z-scored Amplitude')
plt.ylim(-3, 30)
ticks = a1.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
a2 = fig.add_subplot(212)
plt.plot(gavg)
plt.title('Electrode 105, Averaged High Gamma using first 500 ms to Z-score')
plt.xlabel('Time (s)')
plt.ylabel('Z-scored Amplitude')
plt.ylim(-3, 30)
ticks = a2.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
plt.savefig('Figures/091918/z_scoring_comparison.png')

# %% [markdown]
# # Does using a sliding Z-score have any influence on the nature of the autocorrelation?

# %%
gavg_moving_width = autocorr_width(gavg_moving.flatten(), 'sliding')

# %%
fig = plt.figure(figsize = (15, 10))
a = fig.add_subplot(111)
plt.plot(gavg_moving_width)                                                                                             
plt.title('Autocorrelation Zero Time, Moving Z-scoring, Electrode 105, 2 second sliding windows')
plt.ylabel('Autocorrelation zero Time')
plt.xlabel('Time (s)')
ticks = a.get_xticks().tolist()
ticks[:] = [t/100 for t in ticks]
a.set_xticklabels(ticks)
plt.savefig('Figures/091918/autocorrwidth_movingZscore_1.png')

# %% [markdown]
# ## Autocorrelation properties of the stimulus

# %%
dmr = loadmat(r'C:\Users\Ankit\Dropbox\AK & KB\DynRip.cchspct.6oct.100hz.mat')

# %%
# Calculate autocorrelation of random subsets of the DMR
s1 = dmr['spct'][:, 20000:20100] 
s1a = np.zeros(s1.shape)
for i in range(s1.shape[0]):
    s1a[i, :] = np.correlate(s1[i, :] - np.mean(s1[i,:]), s1[i,:] - np.mean(s1[i,:]), mode = 'same')

# %%
plt.pcolor(s1a)

# %% [raw]
# dmr

# %%
dmr
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Wed Jun  5 10:20:23 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'spct': array([[0.04620537, 0.09058822, 0.07729721, ..., 0.01341667, 0.01448431,
#          0.02044945],
#         [0.41263562, 0.6292253 , 0.53494785, ..., 0.09425518, 0.09939809,
#          0.10831817],
#         [0.52086413, 0.82835396, 0.65507341, ..., 0.97192659, 0.77843486,
#          0.73970112],
#         ...,
#         [0.70462758, 0.89829503, 0.93984332, ..., 4.15577892, 3.43965677,
#          2.46796755],
#         [0.46090556, 0.59118011, 0.61787897, ..., 2.15404691, 1.82723258,
#          1.34602308],
#         [0.4523845 , 0.58181854, 0.60952472, ..., 1.75379988, 1.54333253,
#          1.18042949]])}
