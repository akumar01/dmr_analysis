# %%
# %autoreload 2

from helpers import *
from pynwb import NWBHDF5IO
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.signal import correlate
from math import ceil

# %%
# %load_ext autoreload

# %%
# Load in nwb file
io = NWBHDF5IO('R32_B8.nwb')
nwbfile = io.read()

# %%
nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].starting_time
# Out:
# 0.0

# %%
plt.plot(np.array(nwbfile.stimulus['recorded_mark'].data[4000:4040]))

# %%
nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].data.shape
# Out:
# (378940, 128, 54)

# %%
g = np.array(nwbfile.modules['preprocessed'].data_interfaces['Wvlt_4to1200_54band_CAR1'].electrical_series['Wvlt_ECoG128'].data[:, 104, 29])

# %%
a1 = np.correlate(g1[80000:90000] - np.mean(g1[80000:90000]), g1[80000:90000] - np.mean(g1[80000:90000]), mode='same')
a2 = np.correlate(g1[80000:80800] - np.mean(g1[80000:80800]) , g1[80000:80800] - np.mean(g1[80000:80800]), mode='same')
plt.plot(a1[4600:5400])

# %%
x = autocorr_width(g)
plt.plot(x)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]
# C:\Users\Ankit\odrive\Berkeley Google Drive\bouchard\helpers.py:74: RuntimeWarning: invalid value encountered in true_divide
#   autocorr = autocorr[math.floor(autocorr.size/2):]/np.max(autocorr)
# ...

# %%
a1 = np.correlate(gavg[80000:90000] - np.mean(gavg[80000:90000]), gavg[80000:90000] - np.mean(gavg[80000:90000]), mode='same')
plt.plot(a1)

# %%
a1h = a1[ceil(a1.size/2):]
a2h = a2[ceil(a2.size/2):]
a3h = a3[ceil(a3.size/2):]

# %%
a2h.size
# Out:
# 7999

# %%
plt.plot(a1h[0:10])
plt.plot(a2h[0:10])
plt.plot(a3h[0:10])

# %%
plt.plot(g1[8000:8400])

# %%
np.array(nwbfile.stimulus['recorded_mark'].data[:]).shape
# Out:
# (378937, 1)

# %%
x = np.zeros(3040)

# %%
x.shape
# Out:
# (3040,)

# %%
x[:-3].shape
# Out:
# (3037,)

# %%
data_proc = process_freq_bands(data)

# %%
data_proc.shape
# Out:
# (378937,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data_proc)

# %%
from scipy.io import savemat

# %%
savemat('channel104.mat', dict([('data_proc', data_proc)]))

# %%
x = load_DMR_spec('C:\Users\Ankit\Dropbox\AK & KB\DynRip.cchspct.6oct.100hz.mat')
# Out:
# [autoreload of helpers failed: Traceback (most recent call last):
#   File "c:\users\ankit\miniconda3\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\users\ankit\miniconda3\lib\site-packages\IPython\extensions\autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "c:\users\ankit\miniconda3\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "c:\users\ankit\miniconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
# ...

# %%
from scipy.io import loadmat

# %%
y = loadmat(r'C:\Users\Ankit\Dropbox\AK & KB\DynRip.cchspct.6oct.100hz.mat')

# %%
x['spct']
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Wed Jun  5 10:20:23 2013',
#  '__version__': '1.0',
#  '__globals__': [],
#  'spct': array([[0.04620537, 0.09058822, 0.07729721, ..., 0.01341667, 0.01448431,
#          0.02044945],
#         [0.41263562, 0.6292253 , 0.53494785, ..., 0.09425518, 0.09939809,
#          0.10831817],
#         [0.52086413, 0.82835396, 0.65507341, ..., 0.97192659, 0.77843486,
#          0.73970112],
#         ...,
#         [0.70462758, 0.89829503, 0.93984332, ..., 4.15577892, 3.43965677,
#          2.46796755],
#         [0.46090556, 0.59118011, 0.61787897, ..., 2.15404691, 1.82723258,
#          1.34602308],
#         [0.4523845 , 0.58181854, 0.60952472, ..., 1.75379988, 1.54333253,
#          1.18042949]])}

# %%
get_gamma_from_grid('R32_B8.nwb')
# Out:
# > c:\users\ankit\odrive\berkeley google drive\bouchard\helpers.py(11)Z_score()
# -> return (data - mean_baseline)/std_baseline
# (Pdb) mean_baseline
# 3.976307e-05
# (Pdb) std_baseline
# 1.7513623e-05
# (Pdb) quit()

# %%
x = loadmat(r'high_gamma_only.mat')

# %%
#plt.rcParams['figure.figsize'] = [15, 22]
fig = plt.figure(figsize=(20,20))
a1 = fig.add_subplot(2, 1, 1)
plt.plot(x['data'][320000:320400,104])
plt.title('Z-scored electrode 105')
plt.ylabel('Z-scored Amplitude')
a1.set_xticklabels([])
a2 = fig.add_subplot(2, 1, 2)
plt.pcolor(spec['spct'][:, 80000:80100])
plt.ylabel('Frequency (bin)')
plt.xlabel('Time (800-801 s)')
a2.set_xticklabels(np.around(np.linspace(800, 801, 6), decimals = 1))
plt.subplots_adjust(wspace = 0)
plt.savefig('combined5.png')

# %%
from scipy.io import loadmat

# %%
spec = loadmat(r'C:\Users\Ankit\Dropbox\AK & KB\DynRip.cchspct.6oct.100hz')

# %%
spec['spct'].shape
# Out:
# (100, 89934)

# %%
plt.plot(stim)

# %%
from scipy import signal

# %%
x = loadmat('high_gamma_only.mat')
x['data'].shape
# Out:
# (378937, 128)

# %%
get_gamma_from_grid('')
x = loadmat('high_gamma_only_chan105.mat')
plt.plot(x['data'].T)
# Out:
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# c:\users\ankit\miniconda3\lib\site-packages\scipy\signal\signaltools.py:3463: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return y[sl]

# %%
xa = autocorr_width(x['data'].T)

# %%
x['data'].shape
# Out:
# (1, 94735)

# %%
plt.plot(xa)
